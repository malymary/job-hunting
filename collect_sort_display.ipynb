# %%
from functions import dump_json, get_vacancies, \
                        get_full_descriptions, load_from_gdrive, \
                        load_from_device, sort_skills_by_freq, make_cloud

# %%
vacancies = get_vacancies()
print('Parsed', len(vacancies), 'vacancies')
# Out:
# 0it [00:00, ?it/s]
# Parsed 70 vacancies

# %%
vacancies_full = get_full_descriptions(vacancies)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [02:10<00:00,  1.86s/it]

# %%
frequencies = sort_skills_by_freq(vacancies_full)
# Out:
#                                                     Frequency
# AutoCAD                                                    24
# ArchiCAD                                                   16
# Autodesk Revit                                             14
# Работа в команде                                           12
# Грамотная речь                                             11
# Adobe Photoshop                                            10
# Телефонные переговоры                                       8
# Архитектура                                                 6
# Заключение договоров                                        6
# Навыки переговоров                                          5
# Архитектурная деятельность                                  5
# Продажи                                                     5
# Навыки продаж                                               5
# Сопровождение клиентов                                      4
# ...

# %%
make_cloud(frequencies)
# Out:
# Топ навыков для позиции Архитектор:
# <PIL.Image.Image image mode=RGB size=800x600>
